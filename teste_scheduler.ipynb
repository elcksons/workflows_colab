# %% [markdown]
# <a href="https://colab.research.google.com/github/elcksons/workflows_colab/blob/main/teste_scheduler.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = {

    'Nome': ['Ana', 'Bruno', 'Carla', 'Daniel', 'Eduarda', 'Felipe', 'Gabriela', 'Hugo', 'Isabela', 'João'],
    'Idade': [28, 34, 29, 42, 31, 25, 36, 30, 27, 33]
}
# Out:
# {'Nome': ['Ana', 'Bruno', 'Carla', 'Daniel', 'Eduarda', 'Felipe', 'Gabriela', 'Hugo', 'Isabela', 'João'], 'Idade': [28, 34, 29, 42, 31, 25, 36, 30, 27, 33]}

# %%
df = pd.DataFrame(df)
df
# Out:
#        Nome  Idade
# 0       Ana     28
# 1     Bruno     34
# 2     Carla     29
# 3    Daniel     42
# 4   Eduarda     31
# 5    Felipe     25
# 6  Gabriela     36
# 7      Hugo     30
# 8   Isabela     27
# 9      João     33

# %%
df.to_csv('dados.csv', index=False)
